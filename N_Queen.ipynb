# %%
from itertools import permutations

# %%
N=4
sol=0
cols=range(N)

# %%
k=[]
j=[]
for combo in permutations(cols):
    #print("combo")
    k=[]
    j=[]
    print (combo)
    for i in cols:
        k.append(combo[i] + i)
        j.append(combo[i]-i)
        print (set(k))
        print (set(j))
        #print ("k value")
        #print (k)
        #print("set")
        print (len(set(k)) & len(set(j)))
        if len(set(k)) & len(set(j)) == N:
            print (k,j)
            print ("solution")
            print (combo)
        #else:
            #print("no Solution")
# Out:
# (0, 1, 2, 3)
# {0}
# {0}
# 1
# {0, 2}
# {0}
# 0
# {0, 2, 4}
# {0}
# 1
# {0, 2, 4, 6}
# {0}
# 0
# (0, 1, 3, 2)
# {0}
# {0}
# 1
# {0, 2}
# {0}
# 0
# {0, 2, 5}
# {0, 1}
# 2
# {0, 2, 5}
# {0, 1, -1}
# 3
# (0, 2, 1, 3)
# {0}
# {0}
# 1
# {0, 3}
# {0, 1}
# 2
# {0, 3}
# {0, 1, -1}
# 2
# {0, 3, 6}
# {0, 1, -1}
# 3
# (0, 2, 3, 1)
# {0}
# {0}
# 1
# {0, 3}
# {0, 1}
# 2
# {0, 3, 5}
# {0, 1}
# 2
# {0, 3, 4, 5}
# {0, 1, -2}
# 0
# (0, 3, 1, 2)
# {0}
# {0}
# 1
# {0, 4}
# {0, 2}
# 2
# {0, 3, 4}
# {0, 2, -1}
# 3
# {0, 3, 4, 5}
# {0, 2, -1}
# 0
# (0, 3, 2, 1)
# {0}
# {0}
# 1
# {0, 4}
# {0, 2}
# 2
# {0, 4}
# {0, 2}
# 2
# {0, 4}
# {0, 2, -2}
# 2
# (1, 0, 2, 3)
# {1}
# {1}
# 1
# {1}
# {1, -1}
# 0
# {1, 4}
# {0, 1, -1}
# 2
# {1, 4, 6}
# {0, 1, -1}
# 3
# (1, 0, 3, 2)
# {1}
# {1}
# 1
# {1}
# {1, -1}
# 0
# {1, 5}
# {1, -1}
# 2
# {1, 5}
# {1, -1}
# 2
# (1, 2, 0, 3)
# {1}
# {1}
# 1
# {1, 3}
# {1}
# 0
# {1, 2, 3}
# {1, -2}
# 2
# {1, 2, 3, 6}
# {0, 1, -2}
# 0
# (1, 2, 3, 0)
# {1}
# {1}
# 1
# {1, 3}
# {1}
# 0
# ...

# %%
lis=[1,22,22,3,44,44]
print (type(set(lis)))
# Out:
# <class 'set'>
